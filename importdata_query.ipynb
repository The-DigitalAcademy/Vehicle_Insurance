# %% [markdown]
# CODE FOR IMPORTING DATA INTO TABLES

# %%
from sqlalchemy import create_engine
import pandas as pd
# Create a database connection
database_url = "postgresql://dylan:super123duper@129.232.211.166:5432/vehicle_insurancedb"

engine = create_engine(database_url)

# %%
insurance = pd.read_csv('/Users/tshmacm1167/Desktop/Vehicle_Insurance/normalized data/insurance_new.csv')

# %%
gender = pd.read_csv('/Users/tshmacm1167/Desktop/Vehicle_Insurance/normalized data/gender.csv')

# %%
gender.to_sql('gender',engine, if_exists="append", index= False)
# Out:
# 2

# %%
gender
# Out:
#    gender_id  gender
# 0          1  Female
# 1     175021    Male

# %%
vehicle_age = pd.read_csv('/Users/tshmacm1167/Desktop/Vehicle_Insurance/normalized data/vehicle_age.csv')

# %%
vehicle_age.to_sql('vehicle_age', engine, if_exists='append', index=False)
# Out:
# 3

# %%
vehicle = pd.read_csv('/Users/tshmacm1167/Desktop/Vehicle_Insurance/normalized data/vehicle.csv')

# %%
insurance
# Out:
#         Unnamed: 0  gender  age  region_code vehicle_age vehicle_damage  \
# 0                0    Male   44           28   > 2 Years            Yes
# 1                1    Male   76            3    1-2 Year             No
# 2                2    Male   47           28   > 2 Years            Yes
# 3                3    Male   21           11    < 1 Year             No
# 4                4  Female   29           41    < 1 Year             No
# ...            ...     ...  ...          ...         ...            ...
# 381104      381104    Male   74           26    1-2 Year             No
# 381105      381105    Male   30           37    < 1 Year             No
# 381106      381106    Male   21           30    < 1 Year             No
# 381107      381107  Female   68           14   > 2 Years            Yes
# 381108      381108    Male   46           29    1-2 Year             No
#
#         vintage  response  d_license  gender_id  prev_insured   rc_id   ph_id  \
# ...

# %%
vehicles = insurance[['va_id','ph_id','vehicle_damage','vehicle_id']]


#reading_from_the_engine.to_sql('vehicles', engine, if_exists='replace', index=False)

# %%
vehicles.to
# Out:
#          va_id   ph_id vehicle_damage  vehicle_id
# 0       164787       1            Yes      188697
# 1       180794       2             No           1
# 2       164787       3            Yes      188697
# 3            1       4             No           1
# 4            1       5             No           1
# ...        ...     ...            ...         ...
# 381104  180794  381105             No           1
# 381105       1  381106             No           1
# 381106       1  381107             No           1
# 381107  164787  381108            Yes      188697
# 381108  180794  381109             No           1
#
# [381109 rows x 4 columns]

# %%
# Out:
# Empty DataFrame
# Columns: [vehicle_id, va_id, vehicle_damage]
# Index: []

# %%
region_code = pd.read_csv('/Users/tshmacm1167/Desktop/Vehicle_Insurance/normalized data/region_code.csv')

# %%
region_code.to_sql('region_code',engine, if_exists='append', index=False)
# Out:
# 53

# %%
policy_channel = pd.read_csv('/Users/tshmacm1167/Desktop/Vehicle_Insurance/normalized data/policy_channel.csv')

# %%
policy_channel.to_sql('policy_channel',engine, if_exists='append', index=False)
# Out:
# 155
