# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install psycopg2-binary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipython-sql pgspecial psycopg2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql
from sqlalchemy import create_engine
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://dylan:super123duper@129.232.211.166:5432/vehicle_insurancedb
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %% [markdown]
# # Queries for answering customer retention KPI questions

# %%
# %%sql
#
# --What percentage of policy holders renewed their policy?(renewal rate)
#
# SELECT
#     (SUM(CASE WHEN response = 'TRUE' THEN 1 ELSE 0 END) * 100.0 / COUNT(*)) AS renewal_rate
# FROM policy_holder;
# Out:
#  * postgresql://dylan:***@129.232.211.166:5432/vehicle_insurancedb
# 1 rows affected.
# [(Decimal('12.2563361138152077'),)]

# %%
# %%sql
#
# --what percentage of policy holders are first time buyers vs previously insured.
#
# SELECT
#     prev_insured,
#     COUNT(*) AS total_customers,
#     (COUNT(*) * 100.0 / (SELECT COUNT(*) FROM policy_holder)) AS pc_rate
#
# FROM policy_holder
# GROUP BY prev_insured;
# Out:
#  * postgresql://dylan:***@129.232.211.166:5432/vehicle_insurancedb
# 2 rows affected.
# [(False, 206481, Decimal('54.1789881634912846')),
#  (True, 174628, Decimal('45.8210118365087154'))]

# %%
# %%sql
#
# --which demographics have highest renewal rate?
#
# WITH age_groups AS (
#     SELECT
#         CASE
#             WHEN age BETWEEN 18 AND 28 THEN '18-28'
#             WHEN age BETWEEN 29 AND 38 THEN '29-38'
#             WHEN age BETWEEN 39 AND 48 THEN '39-48'
#             WHEN age BETWEEN 49 AND 58 THEN '49-58'
#             ELSE '59+'
#         END AS age_group,
#         gender,
#         CAST(region_code AS TEXT) AS region_code,
#         (SUM(CASE WHEN response = 1 THEN 1 ELSE 0 END) * 100.0 / COUNT(*)) AS renewal_rate
# FROM insurancest
# GROUP BY age_group, gender, region_code)
#
# SELECT *
# FROM age_groups
# ORDER BY renewal_rate DESC
# Out:
#  * postgresql://dylan:***@129.232.211.166:5432/vehicle_insurancedb
# 530 rows affected.
# [('29-38', 'Male', '51', Decimal('35.7142857142857143')),
#  ('29-38', 'Male', '23', Decimal('28.5123966942148760')),
#  ('39-48', 'Male', '11', Decimal('27.7556440903054449')),
#  ('39-48', 'Male', '29', Decimal('27.3424190800681431')),
#  ('29-38', 'Female', '52', Decimal('27.2727272727272727')),
#  ('29-38', 'Male', '4', Decimal('26.5402843601895735')),
#  ('29-38', 'Female', '39', Decimal('26.4900662251655629')),
#  ('39-48', 'Female', '40', Decimal('26.4367816091954023')),
#  ('39-48', 'Male', '24', Decimal('26.0714285714285714')),
#  ('29-38', 'Male', '19', Decimal('26.0000000000000000')),
#  ('29-38', 'Male', '3', Decimal('25.7383966244725738')),
#  ('39-48', 'Male', '40', Decimal('25.5813953488372093')),
#  ('39-48', 'Male', '35', Decimal('25.5372945638432364')),
#  ('39-48', 'Female', '19', Decimal('25.4777070063694268')),
#  ('29-38', 'Male', '24', Decimal('25.4716981132075472')),
# ...

# %%
# %%sql
#
# --On avevarge, how long does it take a policy holder to renew/switch  their policy?
#
# SELECT
# response,
# AVG(vintage) AS avg_vintage
# FROM policy_holder
# GROUP BY response;
# Out:
#  * postgresql://dylan:***@129.232.211.166:5432/vehicle_insurancedb
# 2 rows affected.
# [(False, Decimal('154.3802433619717762')),
#  (True, Decimal('154.1122457717833440'))]

# %% [markdown]
# # Queries for answering sales performance and distributiion questions

# %%
# %%sql
#
# --which channels drives most policy pucahses?
#
# SELECT
# policy_channel,
# COUNT(*) AS total_policies
# FROM insurancest
# GROUP BY policy_channel
# ORDER BY total_policies DESC;
# Out:
#  * postgresql://dylan:***@129.232.211.166:5432/vehicle_insurancedb
# 155 rows affected.
# [(152.0, 134784),
#  (26.0, 79700),
#  (124.0, 73995),
#  (160.0, 21779),
#  (156.0, 10661),
#  (122.0, 9930),
#  (157.0, 6684),
#  (154.0, 5993),
#  (151.0, 3885),
#  (163.0, 2893),
#  (13.0, 1865),
#  (25.0, 1848),
#  (7.0, 1598),
#  (8.0, 1515),
#  (30.0, 1410),
#  (55.0, 1264),
#  (155.0, 1234),
#  (11.0, 1203),
#  (1.0, 1074),
#  (52.0, 1055),
#  (125.0, 1026),
#  (15.0, 888),
#  (29.0, 843),
#  (12.0, 783),
#  (120.0, 769),
#  (24.0, 750),
#  (31.0, 631),
#  (14.0, 622),
#  (153.0, 607),
#  (61.0, 579),
#  (16.0, 523),
#  (3.0, 523),
#  (60.0, 517),
#  (4.0, 509),
#  (158.0, 492),
#  (23.0, 422),
#  (22.0, 332),
#  (150.0, 312),
#  (10.0, 264),
#  (19.0, 222),
#  (136.0, 185),
#  (147.0, 184),
#  (109.0, 175),
#  (145.0, 174),
#  (9.0, 169),
#  (18.0, 167),
#  (91.0, 158),
#  (116.0, 154),
#  (37.0, 152),
#  (21.0, 148),
#  (139.0, 143),
#  (128.0, 137),
#  (42.0, 132),
#  (59.0, 127),
# ...

# %%
# %%sql
#
# --which channels have highest conversion rate?
#
# SELECT
#    policy_channel,
#     (COUNT(CASE WHEN response = 1 THEN 1 END) * 100.0 / COUNT(*)) AS conversion_rate
# FROM insurancest
# GROUP BY policy_channel
# ORDER BY conversion_rate DESC;
# Out:
#  * postgresql://dylan:***@129.232.211.166:5432/vehicle_insurancedb
# 155 rows affected.
# [(123.0, Decimal('100.0000000000000000')),
#  (43.0, Decimal('100.0000000000000000')),
#  (28.0, Decimal('33.3333333333333333')),
#  (27.0, Decimal('33.3333333333333333')),
#  (36.0, Decimal('32.6923076923076923')),
#  (155.0, Decimal('32.0097244732576985')),
#  (163.0, Decimal('30.4182509505703422')),
#  (3.0, Decimal('30.4015296367112811')),
#  (121.0, Decimal('29.6875000000000000')),
#  (101.0, Decimal('28.5714285714285714')),
#  (80.0, Decimal('28.5714285714285714')),
#  (81.0, Decimal('28.5714285714285714')),
#  (87.0, Decimal('28.5714285714285714')),
#  (158.0, Decimal('27.4390243902439024')),
#  (90.0, Decimal('26.9230769230769231')),
#  (157.0, Decimal('26.8402154398563734')),
#  (31.0, Decimal('25.3565768621236133')),
#  (100.0, Decimal('25.0000000000000000')),
#  (2.0, Decimal('25.0000000000000000')),
#  (68.0, Decimal('25.0000000000000000')),
# ...

# %%
# %%sql
#
# --which regions generate most policy sales?
#
# SELECT
# region_code,
# COUNT(*) AS total_policies
# FROM insurancest
# GROUP BY region_code
# ORDER BY total_policies DESC;
# Out:
#  * postgresql://dylan:***@129.232.211.166:5432/vehicle_insurancedb
# 53 rows affected.
# [(28.0, 106415),
#  (8.0, 33877),
#  (46.0, 19749),
#  (41.0, 18263),
#  (15.0, 13308),
#  (30.0, 12191),
#  (29.0, 11065),
#  (50.0, 10243),
#  (3.0, 9251),
#  (11.0, 9232),
#  (36.0, 8797),
#  (33.0, 7654),
#  (47.0, 7436),
#  (35.0, 6942),
#  (6.0, 6280),
#  (45.0, 5605),
#  (37.0, 5501),
#  (18.0, 5153),
#  (48.0, 4681),
#  (14.0, 4678),
#  (39.0, 4644),
#  (10.0, 4374),
#  (21.0, 4266),
#  (2.0, 4038),
#  (13.0, 4036),
#  (7.0, 3279),
#  (12.0, 3198),
#  (9.0, 3101),
#  (27.0, 2823),
#  (32.0, 2787),
#  (43.0, 2639),
#  (17.0, 2617),
#  (26.0, 2587),
#  (25.0, 2503),
#  (24.0, 2415),
#  (38.0, 2026),
#  (0.0, 2021),
#  (16.0, 2007),
#  (31.0, 1960),
#  (23.0, 1960),
#  (20.0, 1935),
#  (49.0, 1832),
#  (4.0, 1801),
#  (34.0, 1664),
#  (19.0, 1535),
#  (22.0, 1309),
#  (40.0, 1295),
#  (5.0, 1279),
#  (1.0, 1008),
#  (44.0, 808),
#  (42.0, 591),
#  (52.0, 267),
#  (51.0, 183)]

# %% [markdown]
# # Queries for answering revenue questions

# %%
# %%sql
#
# --what is the total revenue generated from these policy holders?
#
# SELECT
#     SUM(premium) AS total_revenue
# FROM policy_holder;
# Out:
#  * postgresql://dylan:***@129.232.211.166:5432/vehicle_insurancedb
# 1 rows affected.
# [(11648363949,)]

# %%
# %%sql
#
# --what is the average premium per policy holder?
#
# SELECT
#     AVG(premium) AS avg_premium
# FROM policy_holder;
# Out:
#  * postgresql://dylan:***@129.232.211.166:5432/vehicle_insurancedb
# 1 rows affected.
# [(Decimal('30564.389581458323'),)]

# %%
# %%sql
#
# --are younger or older policy holders paying higher premiums?
#
# SELECT
#     age,
#     AVG(premium) AS avg_premium
# FROM policy_holder
# GROUP BY age
# ORDER BY avg_premium DESC;
# Out:
#  * postgresql://dylan:***@129.232.211.166:5432/vehicle_insurancedb
# 66 rows affected.
# [(82, Decimal('37705.379310344828')),
#  (84, Decimal('35440.818181818182')),
#  (77, Decimal('34903.633285302594')),
#  (71, Decimal('34868.950268161872')),
#  (75, Decimal('34746.913395638629')),
#  (78, Decimal('34681.101973684211')),
#  (76, Decimal('34640.320200573066')),
#  (72, Decimal('34403.468796068796')),
#  (73, Decimal('34284.349610389610')),
#  (74, Decimal('34177.919213973799')),
#  (69, Decimal('34168.190909090909')),
#  (67, Decimal('34016.763719512195')),
#  (80, Decimal('33945.685368536854')),
#  (66, Decimal('33610.774678899083')),
#  (79, Decimal('33283.939890710383')),
#  (68, Decimal('33179.472950819672')),
#  (70, Decimal('33083.737760749255')),
#  (64, Decimal('33081.865614035088')),
#  (62, Decimal('32800.759020618557')),
#  (63, Decimal('32796.128404669261')),
#  (65, Decimal('32748.800071658904')),
#  (58, Decimal('32670.781004709576')),
# ...

# %%
# %%sql
#
# --does pricing vary by region?
#
# SELECT
#     region_code,
#     AVG(premium) AS avg_premium
# FROM insurancest
# GROUP BY region_code
# ORDER BY avg_premium DESC;
# Out:
#  * postgresql://dylan:***@129.232.211.166:5432/vehicle_insurancedb
# 53 rows affected.
# [(28.0, 38668.865244561384),
#  (8.0, 36467.98524072379),
#  (17.0, 31487.48070309515),
#  (50.0, 30955.099287318168),
#  (41.0, 30949.127470842686),
#  (52.0, 30334.44194756554),
#  (47.0, 30224.63017751479),
#  (15.0, 29624.52081454764),
#  (29.0, 29414.511793944872),
#  (36.0, 29376.265772422415),
#  (26.0, 29193.88635485118),
#  (37.0, 28501.944919105616),
#  (9.0, 28369.136407610447),
#  (51.0, 28013.092896174865),
#  (33.0, 27764.45152861249),
#  (11.0, 27607.28314558059),
#  (46.0, 27207.02086181579),
#  (2.0, 26955.2127290738),
#  (39.0, 26882.69875107666),
#  (35.0, 26832.931143762606),
#  (18.0, 26812.46730060159),
#  (34.0, 26699.12560096154),
#  (19.0, 26575.475570032573),
#  (40.0, 26387.699613899615),
#  (43.0, 26068.76695718075),
#  (14.0, 25807.087858059),
#  (24.0, 25767.9933747412),
#  (25.0, 25689.397123451858),
#  (30.0, 25483.349356082355),
#  (7.0, 25466.419945105215),
# ...

# %% [markdown]
# # Queries for risk assessment questions

# %%
# %%sql
#
# --what percentage of customers have reported vehicle damage in the past?
#
# SELECT
#     (COUNT(CASE WHEN vehicle_damage = 'Yes' THEN 1 END) * 100.0 / COUNT(*)) AS damage_rate
# FROM insurancest
# Out:
#  * postgresql://dylan:***@129.232.211.166:5432/vehicle_insurancedb
# 1 rows affected.
# [(Decimal('50.4876557625246321'),)]

# %%
# %%sql
#
# --Do customers with older vehicles have a higher likelihood of policy_renewal?
#
# SELECT
#     vehicle_age,
#     (COUNT(CASE WHEN response = 1 THEN 1 END) * 100.0 / COUNT(*)) AS renewal_rate
# FROM insurancest
# GROUP BY vehicle_age
# ORDER BY renewal_rate DESC;
# Out:
#  * postgresql://dylan:***@129.232.211.166:5432/vehicle_insurancedb
# 3 rows affected.
# [('> 2 Years', Decimal('29.3746485912413319')),
#  ('1-2 Year', Decimal('17.3755466363146229')),
#  ('< 1 Year', Decimal('4.3705169128445378'))]

# %%
# %%sql
#
# --which regions have highest vehicle damage rates?
#
# SELECT
#     region_code,
#     (COUNT(CASE WHEN vehicle_damage = 'Yes' THEN 1 END) * 100.0 / COUNT(*)) AS damage_rate
# FROM insurancest
# GROUP BY region_code
# ORDER BY damage_rate DESC;
# Out:
#  * postgresql://dylan:***@129.232.211.166:5432/vehicle_insurancedb
# 53 rows affected.
# [(28.0, Decimal('66.0019734060047926')),
#  (38.0, Decimal('64.0671273445212241')),
#  (20.0, Decimal('62.8940568475452196')),
#  (1.0, Decimal('62.5000000000000000')),
#  (19.0, Decimal('61.2377850162866450')),
#  (48.0, Decimal('60.0939970091860714')),
#  (40.0, Decimal('60.0772200772200772')),
#  (5.0, Decimal('58.7177482408131353')),
#  (0.0, Decimal('58.5848589807026225')),
#  (24.0, Decimal('58.0124223602484472')),
#  (51.0, Decimal('57.9234972677595628')),
#  (31.0, Decimal('56.8877551020408163')),
#  (39.0, Decimal('56.3092161929371232')),
#  (4.0, Decimal('56.1354802887284842')),
#  (7.0, Decimal('54.8947849954254346')),
#  (26.0, Decimal('54.8898337843061461')),
#  (49.0, Decimal('54.8580786026200873')),
#  (34.0, Decimal('52.9447115384615385')),
#  (23.0, Decimal('52.4489795918367347')),
#  (43.0, Decimal('51.9136036377415688')),
#  (42.0, Decimal('51.7766497461928934')),
# ...

# %%
# %%sql
#
# --How do damage and age affect premium?
#
# SELECT
#     vehicle_age,
#     vehicle_damage,
#     AVG(premium) AS avg_premium
# FROM insurancest
# GROUP BY vehicle_age, vehicle_damage
# ORDER BY avg_premium DESC;
# Out:
#  * postgresql://dylan:***@129.232.211.166:5432/vehicle_insurancedb
# 6 rows affected.
# [('> 2 Years', 'Yes', 35673.45185092546),
#  ('1-2 Year', 'Yes', 30635.62101774225),
#  ('< 1 Year', 'No', 30451.774303113474),
#  ('1-2 Year', 'No', 30324.30360239142),
#  ('< 1 Year', 'Yes', 29315.87961656569),
#  ('> 2 Years', 'No', 15448.733333333334)]
